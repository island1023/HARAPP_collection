# %%
# 安装适配 Python 3.12 的转换全家桶
# !pip install onnx==1.16.1 onnxsim onnx2tf ai-edge-litert \
             nvidia-pyindex onnx-graphsurgeon \
             sng4onnx snc4onnx sne4onnx snd4onnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 77.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 14.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 111.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.8 MB/s eta 0:00:00
# ...
#   Created wheel for onnxsim: filename=onnxsim-0.4.36-cp312-cp312-linux_x86_64.whl size=2200374 sha256=754af42a7ffe34e4330d300e8d1efe28a543dbe1284d59bcc0771b6592861f49
#   Stored in directory: /root/.cache/pip/wheels/73/5d/cc/db1350d9fabfe7f8442b5d97aff2ff543fc253277f71a6508f
# ...

# %%
# !python train_transformer1.py
# Out:
# 正在加载数据并进行深度清洗...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch 01 | Loss: 0.6697 | Acc: 85.36%
# Epoch 02 | Loss: 0.3338 | Acc: 90.13%
# Epoch 03 | Loss: 0.2491 | Acc: 91.90%
# Epoch 04 | Loss: 0.2083 | Acc: 91.96%
# Epoch 05 | Loss: 0.1868 | Acc: 94.76%
# Epoch 06 | Loss: 0.1656 | Acc: 94.93%
# Epoch 07 | Loss: 0.1648 | Acc: 94.99%
# Epoch 08 | Loss: 0.1467 | Acc: 95.52%
# Epoch 09 | Loss: 0.1368 | Acc: 95.02%
# Epoch 10 | Loss: 0.1334 | Acc: 95.64%
#
# 训练完成！最高准确率: 95.64%。正在导出兼容性优化的 ONNX...
# Traceback (most recent call last):
#   File "/content/train_transformer1.py", line 171, in <module>
#     torch.onnx.export(
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/__init__.py", line 282, in export
# ...

# %%
# !pip install onnxscript onnx==1.16.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.4/693.4 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 14.2 MB/s eta 0:00:00
# ...

# %%
# !python train_transformer1.py
# Out:
# 正在加载数据并进行深度清洗...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch 01 | Loss: 0.6340 | Acc: 85.57%
# Epoch 02 | Loss: 0.3321 | Acc: 88.66%
# Epoch 03 | Loss: 0.2496 | Acc: 92.46%
# Epoch 04 | Loss: 0.2080 | Acc: 93.46%
# Epoch 05 | Loss: 0.1861 | Acc: 94.37%
# Epoch 06 | Loss: 0.1658 | Acc: 94.55%
# Epoch 07 | Loss: 0.1585 | Acc: 94.61%
# Epoch 08 | Loss: 0.1431 | Acc: 95.05%
# Epoch 09 | Loss: 0.1335 | Acc: 95.41%
# Epoch 10 | Loss: 0.1349 | Acc: 95.70%
#
# 训练完成！最高准确率: 95.70%。正在导出兼容性优化的 ONNX...
# ...

# %%
# !onnxsim mobilevit_wisdm_v11.onnx mobilevit_v11_sim.onnx
# Out:
# Installing onnxruntime by `/usr/bin/python3 -m pip install onnxruntime`, please
# wait for a moment..
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 118.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
# ...
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                    ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add                │ 12             │ 12               │
# │ Constant           │ 46             │ 46               │
# │ Conv               │ 3              │ 3                │
# │ Gather             │ 6              │ 6                │
# │ Gemm               │ 3              │ 3                │
# │ LayerNormalization │ 4              │ 4                │
# ...

# %%
# !onnx2tf -i mobilevit_v11_sim.onnx -o saved_model_v11
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766828933.102680    8066 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766828933.108725    8066 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766828933.124220    8066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766828933.124248    8066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766828933.124252    8066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import tensorflow as tf

# 加载中间目录
converter = tf.lite.TFLiteConverter.from_saved_model("saved_model_v11")

# 开启必要的兼容算子
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
    tf.lite.OpsSet.SELECT_TF_OPS
]

# 开启 FP16 压缩，大幅减小体积
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

try:
    tflite_model = converter.convert()
    with open("mobilevit_wisdm_final.tflite", "wb") as f:
        f.write(tflite_model)
    print("🎉 最终目标达成！请下载 mobilevit_wisdm_final.tflite")
except Exception as e:
    print(f"❌ 导出出错：{e}")
# Out:
# 🎉 最终目标达成！请下载 mobilevit_wisdm_final.tflite
